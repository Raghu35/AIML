# %% [markdown]
# # 05. Object-Oriented Programming
#
# This notebook introduces classes, objects, and inheritance.
#
# **What it is:** OOP organizes code into classes (blueprints) and objects (instances) that combine data and behavior in one place.
#
# **Where we use it:** Application design, frameworks, game development, and any system modeling real-world entities like users or products.
#
# **Why we use it:** It makes code reusable, modular, and easier to scale as projects grow.
#
# > See [Module2/01_oop.ipynb](../Module2/01_oop.ipynb) for the full Module 2 OOP walkthrough.

# %%
# Class and object example
class Dog:
    def __init__(self, name):
        self.name = name

    def bark(self):
        return f"{self.name} says woof!"

my_dog = Dog("Bruno")
print(my_dog.bark())

# %%
# Inheritance example
class Animal:
    def speak(self):
        return "Animal sound"

class Cat(Animal):
    def speak(self):
        return "Meow"

print(Cat().speak())

# %%
# OOP concepts: class, object, constructor, inheritance, polymorphism, encapsulation, abstraction, magic methods
from abc import ABC, abstractmethod

class Animal(ABC):
    species = "Animal"

    def __init__(self, name):
        self.name = name

    @abstractmethod
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return f"{self.name} barks"

    def __str__(self):
        return f"Dog({self.name})"

class Cat(Animal):
    def speak(self):
        return f"{self.name} meows"

class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def get_balance(self):
        return self.__balance

animals = [Dog("Bruno"), Cat("Milo")]
for animal in animals:
    print(animal.speak())

account = BankAccount("Asha", 100)
account.deposit(50)
print(account.get_balance())
print(Dog("Bruno"))
