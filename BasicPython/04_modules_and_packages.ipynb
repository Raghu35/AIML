# %% [markdown]
# # 04. Modules and Packages
#
# This notebook shows how to use built-in Python modules.
#
# What this topic is:
# Modules and packages let us reuse existing code written by others and organize our own code better.
#
# Where we use it:
# They are used in almost every Python project for tasks such as mathematics, files, dates, and networking.
#
# Why we use it:
# They save time and help us build programs faster with reliable tools.

# %%
# Math and random modules
import math
import random
print(math.sqrt(16))
print(random.randint(1, 10))

# %%
# Date and time module
from datetime import datetime
print(datetime.now())
